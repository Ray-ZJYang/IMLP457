# %% [markdown]
# ## 基礎題 - 算出斜率w與截距b
#
# y = wx + b
#
# 記得計算前X須符合資料格式
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#將模型工具指派給一變數做使用
#注意轉換x得格式1D->2D
#將x,y資料導入LinearRegression演算法做訓練
#列印出訓練完成之函數的斜率與截距
from sklearn.linear_model import LinearRegression
x_reshaped=x.reshape(-1, 1)
model=LinearRegression()
model.fit(x_reshaped, y)

print("斜率 w= {:.4f}".format(model.coef_[0]))
print("截距 b= {:.4f}".format(model.intercept_))
# Out:
# 斜率 w= 1.6170
# 截距 b= 0.2731

# %% [markdown]
# ## 進階題 - 切割資料集分別做訓練與預測(訓練資料80%、測試資料20%)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#匯入在sklearn.model_selection套件裡面的train_test_split模組
#切割數據集(訓練資料80%、測試資料20%，設定random_state=20)
#畫出訓練資料集的matplotlib圖形m
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X = x.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)
model = LinearRegression()
model.fit(X_train, y_train)
w = model.coef_[0]
b = model.intercept_
print(f"斜率 w = {w:.4f}")
print(f"截距 b = {b:.4f}")
# Out:
# 斜率 w = 1.6066
# 截距 b = 0.3680

# %%
y_pred_test = model.predict(X_test)
r2_tr  = model.score(X_train, y_train)
r2_te  = model.score(X_test,  y_test)
mae_te = mean_absolute_error(y_test, y_pred_test)
mse_te = mean_squared_error(y_test, y_pred_test)

print(f"Train R² = {r2_tr:.4f}")
print(f"Test  R² = {r2_te:.4f}  |  MAE = {mae_te:.4f}  |  MSE = {mse_te:.4f}")
# Out:
# Train R² = 0.9894
# Test  R² = 0.9838  |  MAE = 0.5120  |  MSE = 0.4134

# %%
xs = np.linspace(X.min(), X.max(), 200).reshape(-1, 1)
ys = model.predict(xs)

plt.figure(figsize=(8,5))
plt.scatter(X_train, y_train, label="Train", alpha=0.8)
plt.scatter(X_test,  y_test,  label="Test",  marker="x", s=80)
plt.plot(xs, ys, label="Fitted line", linewidth=2)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression with Train/Test Split (80%/20%)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 用訓練資料來 fit 函數
# 1. 只用訓練資料集的資料進行linear regression演算法<br>
# 2. 並計算出訓練階段的MSE
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_train.PNG)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train = x.reshape(-1, 1)
y_train = y
model = LinearRegression()
model.fit(X_train, y_train)

w = model.coef_[0]
b = model.intercept_
print(f"斜率 w = {w:.4f}")
print(f"截距 b = {b:.4f}")
# Out:
# 斜率 w = 1.6170
# 截距 b = 0.2731

# %%
y_pred_train = model.predict(X_train)

mse_train = mean_squared_error(y_train, y_pred_train)
print(f"訓練集 MSE = {mse_train:.4f}")
# Out:
# 訓練集 MSE = 0.2627

# %%
plt.scatter(x, y)         
plt.plot(x, y_pred_train, 'r')  # 紅色線

plt.show()

# %% [markdown]
# ## 將訓練出來的函數預測測試集的X值
# 1. 使用剛剛訓練出來的模型進行測試資料集的資料預測*注意reshape<br>
# 使用X = 2.44897959，預測出來數值應該為 4.3025375<br>
# 所有測試集資料
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
y_pred_test = model.predict(X_test)

# %%
print(f"測試資料第一筆 X = {X_test[0][0]:.4f}")
print(f"預測出的 y 值 = {y_pred_test[0]:.4f}")
# Out:
# 測試資料第一筆 X = 2.4490
# 預測出的 y 值 = 4.2332

# %% [markdown]
# 2. 並計算出測試階段的MSE

# %%
mse_test = mean_squared_error(y_test, y_pred_test)
print(f"測試集 MSE = {mse_test:.4f}")
# Out:
# 測試集 MSE = 0.3894

# %% [markdown]
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_test.PNG)

# %%
y_pred_test = model.predict(X_test)
mse_test = mean_squared_error(y_test, y_pred_test)

# %%
plt.figure(figsize=(6,4))
plt.scatter(X_test, y_test, label='Ground Truth', color='blue')  
plt.scatter(X_test, y_pred_test, label='Predict', color='red')  
plt.title(f"f(x)={model.coef_[0]:.1f}x+{model.intercept_:.1f}, mse={mse_test:.2f}")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
